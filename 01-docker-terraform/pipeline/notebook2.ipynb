# %%
import pandas as pd

# %%
prefix = 'd37ci6vzurychx.cloudfront.net/trip-data'
url = f'https://{prefix}/green_tripdata_2025-11.parquet'
url
# Out:
# 'https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet'

# %%
df_trip_data = pd.read_parquet(url)

# %%
df_trip_data
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1             2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2             2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3             2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4             1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
# ...         ...                  ...                   ...                ...
# 46907         2  2025-11-30 19:58:34   2025-11-30 20:14:28               None
# 46908         2  2025-11-30 19:34:00   2025-11-30 19:46:00               None
# 46909         2  2025-11-30 21:46:46   2025-11-30 22:17:55               None
# 46910         2  2025-11-30 21:00:00   2025-11-30 21:15:00               None
# 46911         2  2025-11-30 23:26:00   2025-11-30 23:42:00               None
#
# ...

# %%
df_trip_data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
# 3         1.0           166           127              1.0           5.44
# 4         1.0           166           262              1.0           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
# !uv add sqlalchemy
# Out:
# Resolved 120 packages in 1ms
# Audited 14 packages in 1ms

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 120 packages in 1ms
# Audited 14 packages in 1ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_trip_data.to_sql(name='trip', con=engine, if_exists='replace')
# Out:
# 912
